# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
np.random.seed(1)

# %%
x = np.random.uniform(1,100,1000)

# %%
y = np.log(x) + np.random.normal(0,0.3,1000)

# %%
data = pd.DataFrame(np.column_stack([x,y]),columns=['x','y'])

# %%
plt.scatter(x, y, s=1, label="log(x) with noise")
plt.plot(np.arange(1, 100), np.log(np.arange(1, 100)), c="b", label="log(x) true function")
plt.xlabel("x")
plt.ylabel("f(x) = log(x)")
plt.legend(loc="best")
plt.title("A Basic Log Function")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()

x = x.reshape(-1,1)
y = y.reshape(-1,1)

linreg.fit(x,y)

linreg.score(x,y)

y_pred = linreg.predict(x)

# %%
plt.scatter(x, y_pred, s=1, label="linear model")
plt.plot(np.arange(1, 100), np.log(np.arange(1, 100)), c="b", label="true log")
plt.xlabel("x")
plt.ylabel("y(pred)")
plt.legend(loc="best")
plt.title("Predicting with Linear")
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x,y)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf.score(x,y)
# Out:
# 0.9752241615018914

# %%
y_pred = rf.predict(x)

# %%
plt.scatter(x, y_pred, s=1, label="rf model")
plt.plot(np.arange(1, 100), np.log(np.arange(1, 100)), c="b", label="true log")
plt.xlabel("x")
plt.ylabel("y(pred)")
plt.legend(loc="best")
plt.title("Predicting with rf")
plt.show()

# %%
rf.decision_path(x)
# Out:
# (<1000x12626 sparse matrix of type '<class 'numpy.int64'>'
#  	with 131280 stored elements in Compressed Sparse Row format>,
#  array([    0,  1251,  2516,  3773,  5066,  6323,  7570,  8871, 10136,
#         11401, 12626], dtype=int32))
